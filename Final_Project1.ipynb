# %%
import pandas as pd
import numpy as np
grad= pd.read_csv("graduation1_bd.csv")
crime=pd.read_csv("crime2_bd.csv")

# %%
grad.rename(columns = {'Cohort Year':'Year'}, inplace = True)

# %%
crime.rename(columns = {'ARREST_YEAR':'Year'}, inplace = True)

# %%
crime
# Out:
#       ARREST_DATE                      PD_DESC PERP_SEX       PERP_RACE  Year  \
# 0      2014-09-16  MARIJUANA, POSSESSION 4 & 5        M           BLACK  2014
# 1      2014-08-25  MARIJUANA, POSSESSION 4 & 5        F           BLACK  2014
# 2      2014-08-04          SALE SCHOOL GROUNDS        M           BLACK  2014
# 3      2014-08-01        MARIJUANA, SALE 4 & 5        M           BLACK  2014
# 4      2014-07-31        MARIJUANA, SALE 4 & 5        M           BLACK  2014
# ...           ...                          ...      ...             ...   ...
# 67490  2012-01-11  MARIJUANA, POSSESSION 4 & 5        M           BLACK  2012
# 67491  2012-01-11        MARIJUANA, SALE 4 & 5        M           BLACK  2012
# 67492  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M  WHITE HISPANIC  2012
# 67493  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M           BLACK  2012
# 67494  2012-01-06        MARIJUANA, SALE 4 & 5        M           BLACK  2012
#
#          Weekday  Day Month
# ...

# %%
final=pd.merge(grad,crime,on=['Year'])

# %%
final.drop(final.columns[[-4,-5,-6]],axis=1,inplace=True)

# %%
final.columns
# Out:
# Index(['District', 'Year', 'Cohort', 'Total Cohort #', 'Total Grads #',
#        'Total Grads % of cohort', 'Total Regents #',
#        'Total Regents % of cohort', 'Total Regents % of grads',
#        'Dropped Out #', 'Dropped Out % of cohort', 'ARREST_DATE', 'PD_DESC',
#        'OFNS_DESC', 'AGE_GROUP', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD',
#        'Y_COORD_CD', 'Latitude', 'Longitude', 'Weekday', 'Day', 'Month'],
#       dtype='object')

# %%
final.drop(final.columns[2],axis=1,inplace=True)

# %%
final
# Out:
#          District  Year  Total Cohort #  Total Grads #  \
# 0               1  2014             957            631
# 1               1  2014             957            631
# 2               1  2014             957            631
# 3               1  2014             957            631
# 4               1  2014             957            631
# ...           ...   ...             ...            ...
# 2159835        32  2012             655            428
# 2159836        32  2012             655            428
# 2159837        32  2012             655            428
# 2159838        32  2012             655            428
# 2159839        32  2012             655            428
#
#          Total Grads % of cohort  Total Regents #  Total Regents % of cohort  \
# 0                           65.9              597                       62.4
# 1                           65.9              597                       62.4
# ...

# %%
final.drop(final.columns[13],axis=1,inplace=True)

# %%
final.columns
# Out:
# Index(['District', 'Year', 'Total Cohort #', 'Total Grads #',
#        'Total Grads % of cohort', 'Total Regents #',
#        'Total Regents % of cohort', 'Total Regents % of grads',
#        'Dropped Out #', 'Dropped Out % of cohort', 'ARREST_DATE', 'PD_DESC',
#        'OFNS_DESC', 'PERP_SEX', 'PERP_RACE', 'X_COORD_CD', 'Y_COORD_CD',
#        'Latitude', 'Longitude', 'Weekday', 'Day', 'Month'],
#       dtype='object')

# %%
final
# Out:
#          District  Year  Total Cohort #  Total Grads #  \
# 0               1  2014             957            631
# 1               1  2014             957            631
# 2               1  2014             957            631
# 3               1  2014             957            631
# 4               1  2014             957            631
# ...           ...   ...             ...            ...
# 2159835        32  2012             655            428
# 2159836        32  2012             655            428
# 2159837        32  2012             655            428
# 2159838        32  2012             655            428
# 2159839        32  2012             655            428
#
#          Total Grads % of cohort  Total Regents #  Total Regents % of cohort  \
# 0                           65.9              597                       62.4
# 1                           65.9              597                       62.4
# ...

# %%
final.drop(final.columns[[-4,-5,-6,-7,-10]],axis=1,inplace=True)

# %%
final
# Out:
#          District  Year  Total Cohort #  Total Grads #  \
# 0               1  2014             957            631
# 1               1  2014             957            631
# 2               1  2014             957            631
# 3               1  2014             957            631
# 4               1  2014             957            631
# ...           ...   ...             ...            ...
# 2159835        32  2012             655            428
# 2159836        32  2012             655            428
# 2159837        32  2012             655            428
# 2159838        32  2012             655            428
# 2159839        32  2012             655            428
#
#          Total Grads % of cohort  Total Regents #  Total Regents % of cohort  \
# 0                           65.9              597                       62.4
# 1                           65.9              597                       62.4
# ...

# %%
final.to_csv(r'C:\Users\user\Downloads\Final_2.csv',index=False)

# %%
final.dtypes
# Out:
# District                       int64
# Year                           int64
# Total Cohort #                 int64
# Total Grads #                  int64
# Total Grads % of cohort      float64
# Total Regents #                int64
# Total Regents % of cohort    float64
# Total Regents % of grads     float64
# Dropped Out #                  int64
# Dropped Out % of cohort      float64
# ARREST_DATE                   object
# PD_DESC                       object
# PERP_SEX                      object
# PERP_RACE                     object
# dtype: object

# %%
final['ARREST_DATE'].value_counts()
# Out:
# 2012-04-20    4864
# 2012-02-03    4512
# 2012-04-04    4448
# 2012-03-13    4416
# 2012-03-22    4416
#               ...
# 2014-12-22      96
# 2013-12-25      64
# 2014-12-27      64
# 2014-12-28      64
# 2014-12-24      32
# Name: ARREST_DATE, Length: 1093, dtype: int64

# %%
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

correlation_data=final.select_dtypes(include=[np.number]).corr()

mask = np.zeros_like(correlation_data, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(11, 9))


cmap = sns.palette="vlag"

sns.heatmap(correlation_data, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5});
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8500\2077770631.py:7: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.zeros_like(correlation_data, dtype=np.bool)

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(final.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()
