# %%
import pandas as pd
import numpy as np
dt = pd.read_csv("bd2.csv")

dt.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                             PD_DESC  KY_CD  \
# 0   236791704  11/22/2021  581.0                                 NaN    NaN
# 1   237354740  12/04/2021  153.0                              RAPE 3  104.0
# 2   236081433  11/09/2021  681.0          CHILD, ENDANGERING WELFARE  233.0
# 3    32311380  06/18/2007  511.0  CONTROLLED SUBSTANCE, POSSESSION 7  235.0
# 4   192799737  01/26/2019  177.0                        SEXUAL ABUSE  116.0
#
#          OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0              NaN  PL 2225001          M           M               28
# 1             RAPE  PL 1302502          F           B               41
# 2       SEX CRIMES  PL 2601001          M           Q              113
# 3  DANGEROUS DRUGS  PL 2200300          M           Q               27
# 4       SEX CRIMES  PL 1306503          F           M               25
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  \
# ...

# %%
dt
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD                             PD_DESC  \
# 0         236791704  11/22/2021  581.0                                 NaN
# 1         237354740  12/04/2021  153.0                              RAPE 3
# 2         236081433  11/09/2021  681.0          CHILD, ENDANGERING WELFARE
# 3          32311380  06/18/2007  511.0  CONTROLLED SUBSTANCE, POSSESSION 7
# 4         192799737  01/26/2019  177.0                        SEXUAL ABUSE
# ...             ...         ...    ...                                 ...
# 5308871    24092381  08/31/2006  223.0            BURGLARY,RESIDENCE,NIGHT
# 5308872    24157849  09/05/2006  397.0     ROBBERY,UNCLASSIFIED,OPEN AREAS
# 5308873    24419289  09/21/2006  511.0  CONTROLLED SUBSTANCE, POSSESSION 7
# 5308874    24130128  09/02/2006  511.0  CONTROLLED SUBSTANCE, POSSESSION 7
# 5308875    24517404  09/27/2006  511.0  CONTROLLED SUBSTANCE, POSSESSION 7
#
# ...

# %%
dt1=dt.loc[dt['AGE_GROUP'].isin(['18-24'])]

# %%
dt1
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD  \
# 3          32311380  06/18/2007  511.0
# 8         238383628  12/28/2021  729.0
# 39        236949124  11/26/2021  105.0
# 40        189228258  10/26/2018  563.0
# 62        190140531  11/18/2018  153.0
# ...             ...         ...    ...
# 5308864    24053688  08/28/2006  569.0
# 5308865    24036530  08/27/2006  113.0
# 5308868    24028494  08/25/2006  849.0
# 5308869    24236779  09/10/2006  617.0
# 5308872    24157849  09/05/2006  397.0
#
#                                             PD_DESC  KY_CD  \
# 3                CONTROLLED SUBSTANCE, POSSESSION 7  235.0
# 8                    FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 39                                STRANGULATION 1ST  106.0
# 40                                     PROSTITUTION  356.0
# 62                                           RAPE 3  104.0
# ...                                             ...    ...
# 5308864                       MARIJUANA, SALE 4 & 5  235.0
# ...

# %%
max(dt1['ARREST_DATE'])
# Out:
# '12/31/2021'

# %%
min(dt1['ARREST_DATE'])
# Out:
# '01/01/2006'

# %%
dt1['ARREST_DATE']=pd.to_datetime(dt1['ARREST_DATE'])
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\2208744414.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dt1['ARREST_DATE']=pd.to_datetime(dt1['ARREST_DATE'])

# %%
df=pd.DataFrame(dt1)

# %%
dt1
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD  \
# 3          32311380  2007-06-18  511.0
# 8         238383628  2021-12-28  729.0
# 39        236949124  2021-11-26  105.0
# 40        189228258  2018-10-26  563.0
# 62        190140531  2018-11-18  153.0
# ...             ...         ...    ...
# 5308864    24053688  2006-08-28  569.0
# 5308865    24036530  2006-08-27  113.0
# 5308868    24028494  2006-08-25  849.0
# 5308869    24236779  2006-09-10  617.0
# 5308872    24157849  2006-09-05  397.0
#
#                                             PD_DESC  KY_CD  \
# 3                CONTROLLED SUBSTANCE, POSSESSION 7  235.0
# 8                    FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 39                                STRANGULATION 1ST  106.0
# 40                                     PROSTITUTION  356.0
# 62                                           RAPE 3  104.0
# ...                                             ...    ...
# 5308864                       MARIJUANA, SALE 4 & 5  235.0
# ...

# %%
df['ARREST_DATE']
# Out:
# 3         2007-06-18
# 8         2021-12-28
# 39        2021-11-26
# 40        2018-10-26
# 62        2018-11-18
#              ...
# 5308864   2006-08-28
# 5308865   2006-08-27
# 5308868   2006-08-25
# 5308869   2006-09-10
# 5308872   2006-09-05
# Name: ARREST_DATE, Length: 1375134, dtype: datetime64[ns]

# %%
df = df[(df['ARREST_DATE'] > '2011-12-31') & (df['ARREST_DATE'] <= '2014-12-31')]

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE  PD_CD  \
# 512402    140379311  2014-12-31  157.0
# 512444    140141998  2014-12-11  157.0
# 512445    140066034  2014-12-05  707.0
# 512447    139933331  2014-12-03  263.0
# 512464    140079962  2014-12-07  105.0
# ...             ...         ...    ...
# 3153114    82489781  2012-01-05  567.0
# 3153157    82489907  2012-01-05  339.0
# 3153181    82518776  2012-01-07  259.0
# 3153196    82490427  2012-01-05  567.0
# 3153201    82519599  2012-01-06  569.0
#
#                                             PD_DESC  KY_CD  \
# 512402                                       RAPE 1  104.0
# 512444                                       RAPE 1  104.0
# 512445              IMPERSONATION 2, PUBLIC SERVANT  340.0
# 512447                                  ARSON 2,3,4  114.0
# 512464                            STRANGULATION 1ST  106.0
# ...                                             ...    ...
# 3153114                 MARIJUANA, POSSESSION 4 & 5  235.0
# ...

# %%
max(df['ARREST_DATE'])
# Out:
# Timestamp('2014-12-31 00:00:00')

# %%
min(df['ARREST_DATE'])
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
m=df.dtypes
print(m)
# Out:
# ARREST_KEY                    int64
# ARREST_DATE          datetime64[ns]
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE           float64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                  float64
# Y_COORD_CD                  float64
# Latitude                    float64
# Longitude                   float64
# Lon_Lat                      object
# dtype: object

# %%
dt['OFNS_DESC'].nunique()
# Out:
# 88

# %%
str(df['ARREST_DATE'].dt.date.min()) + '  to  ' +str(df['ARREST_DATE'].dt.date.max())
# Out:
# '2012-01-01  to  2014-12-31'

# %%
df['OFNS_DESC'].value_counts()
# Out:
# DANGEROUS DRUGS                           67495
# OTHER OFFENSES RELATED TO THEFT           38379
# ASSAULT 3 & RELATED OFFENSES              28021
# OTHER STATE LAWS                          19588
# DANGEROUS WEAPONS                         14802
#                                           ...
# CHILD ABANDONMENT/NON SUPPORT                 9
# HOMICIDE-NEGLIGENT-VEHICLE                    9
# UNLAWFUL POSS. WEAP. ON SCHOOL GROUNDS        5
# OFF. AGNST PUB ORD SENSBLTY &                 2
# ABORTION                                      1
# Name: OFNS_DESC, Length: 68, dtype: int64

# %%
df['PD_DESC'].value_counts()
# Out:
# MARIJUANA, POSSESSION 4 & 5                40222
# THEFT OF SERVICES, UNCLASSIFIED            38304
# ASSAULT 3                                  23402
# NY STATE LAWS,UNCLASSIFIED VIOLATION       19124
# ROBBERY,UNCLASSIFIED,OPEN AREAS            10733
#                                            ...
# CONTROLLED SUBSTANCE, POSSESSI                 1
# NY STATE LAWS,UNCLASSIFIED VIO                 1
# IMPROPER PASSING                               1
# MATERIAL              OFFENSIVE DISPLAY        1
# PEDESTRIAN,WALK/DONT WALK                      1
# Name: PD_DESC, Length: 283, dtype: int64

# %%
df.drop(df.columns[[2,4,6,7,8,9,10]], axis=1, inplace=True)

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                                     PD_DESC  \
# 512402    140379311  2014-12-31                                      RAPE 1
# 512444    140141998  2014-12-11                                      RAPE 1
# 512445    140066034  2014-12-05             IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                                 ARSON 2,3,4
# 512464    140079962  2014-12-07                           STRANGULATION 1ST
# ...             ...         ...                                         ...
# 3153114    82489781  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153157    82489907  2012-01-05  LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED
# 3153181    82518776  2012-01-07  MISCHIEF,CRIMINAL     UNCLASSIFIED 4TH DEG
# 3153196    82490427  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153201    82519599  2012-01-06                       MARIJUANA, SALE 4 & 5
#
# ...

# %%
df['ARREST_YEAR']=df.ARREST_DATE.dt.strftime('%Y')

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                                     PD_DESC  \
# 512402    140379311  2014-12-31                                      RAPE 1
# 512444    140141998  2014-12-11                                      RAPE 1
# 512445    140066034  2014-12-05             IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                                 ARSON 2,3,4
# 512464    140079962  2014-12-07                           STRANGULATION 1ST
# ...             ...         ...                                         ...
# 3153114    82489781  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153157    82489907  2012-01-05  LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED
# 3153181    82518776  2012-01-07  MISCHIEF,CRIMINAL     UNCLASSIFIED 4TH DEG
# 3153196    82490427  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153201    82519599  2012-01-06                       MARIJUANA, SALE 4 & 5
#
# ...

# %%
df.drop(df.columns[[-2]], axis=1, inplace=True)

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                                     PD_DESC  \
# 512402    140379311  2014-12-31                                      RAPE 1
# 512444    140141998  2014-12-11                                      RAPE 1
# 512445    140066034  2014-12-05             IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                                 ARSON 2,3,4
# 512464    140079962  2014-12-07                           STRANGULATION 1ST
# ...             ...         ...                                         ...
# 3153114    82489781  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153157    82489907  2012-01-05  LARCENY,PETIT FROM OPEN AREAS,UNCLASSIFIED
# 3153181    82518776  2012-01-07  MISCHIEF,CRIMINAL     UNCLASSIFIED 4TH DEG
# 3153196    82490427  2012-01-05                 MARIJUANA, POSSESSION 4 & 5
# 3153201    82519599  2012-01-06                       MARIJUANA, SALE 4 & 5
#
# ...

# %%
df1=df['OFNS_DESC']=='DANGEROUS DRUGS'

# %%
df1=df.loc[dt['OFNS_DESC'].isin(['DANGEROUS DRUGS'])]

# %%
df1
# Out:
#          ARREST_KEY ARREST_DATE                      PD_DESC        OFNS_DESC  \
# 512597    138734884  2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 512645    138388215  2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 512672    138052928  2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS
# 512675    138010647  2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# 512679    137995345  2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# ...             ...         ...                          ...              ...
# 3153106    82588479  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153111    82587675  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# 3153114    82489781  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153196    82490427  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153201    82519599  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
#
# ...

# %%
df1.isnull().sum()
# Out:
# ARREST_KEY     0
# ARREST_DATE    0
# PD_DESC        0
# OFNS_DESC      0
# AGE_GROUP      0
# PERP_SEX       0
# PERP_RACE      0
# X_COORD_CD     0
# Y_COORD_CD     0
# Latitude       0
# Longitude      0
# ARREST_YEAR    0
# dtype: int64

# %%
df1.groupby('ARREST_DATE').count()
# Out:
#              ARREST_KEY  PD_DESC  OFNS_DESC  AGE_GROUP  PERP_SEX  PERP_RACE  \
# ARREST_DATE
# 2012-01-01           40       40         40         40        40         40
# 2012-01-02           38       38         38         38        38         38
# 2012-01-03           91       91         91         91        91         91
# 2012-01-04           99       99         99         99        99         99
# 2012-01-05          117      117        117        117       117        117
# ...                 ...      ...        ...        ...       ...        ...
# 2014-12-26           13       13         13         13        13         13
# 2014-12-27            2        2          2          2         2          2
# 2014-12-28            2        2          2          2         2          2
# 2014-12-29            3        3          3          3         3          3
# 2014-12-30            7        7          7          7         7          7
#
# ...

# %%
df1
# Out:
#          ARREST_KEY ARREST_DATE                      PD_DESC        OFNS_DESC  \
# 512597    138734884  2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 512645    138388215  2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 512672    138052928  2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS
# 512675    138010647  2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# 512679    137995345  2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# ...             ...         ...                          ...              ...
# 3153106    82588479  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153111    82587675  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
# 3153114    82489781  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153196    82490427  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS
# 3153201    82519599  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS
#
# ...

# %%
df1.drop(df1.columns[[0]], axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\4110977159.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.columns[[0]], axis=1, inplace=True)

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC        OFNS_DESC AGE_GROUP  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 512672   2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS     18-24
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# ...             ...                          ...              ...       ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
#
# ...

# %%
df1.to_csv(r'C:\Users\user\Downloads\crime1_bd.csv', index=False)

# %%
df1.drop(df1.columns[[-2,-3,-4,-5]], axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\3812186044.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.columns[[-2,-3,-4,-5]], axis=1, inplace=True)

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC        OFNS_DESC AGE_GROUP  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 512672   2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS     18-24
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# ...             ...                          ...              ...       ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS     18-24
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS     18-24
#
#         PERP_SEX       PERP_RACE ARREST_YEAR
# ...

# %%
df1.drop(df1.columns[[3]], axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\2334609676.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.columns[[3]], axis=1, inplace=True)

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC        OFNS_DESC PERP_SEX  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        F
# 512672   2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS        M
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# ...             ...                          ...              ...      ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
#
#               PERP_RACE ARREST_YEAR
# ...

# %%
df1['PERP_RACE'].value_counts()
# Out:
# BLACK                             101659
# WHITE HISPANIC                     59406
# WHITE                              29909
# BLACK HISPANIC                     23141
# ASIAN / PACIFIC ISLANDER            6390
# UNKNOWN                             2389
# AMERICAN INDIAN/ALASKAN NATIVE       420
# Name: PERP_RACE, dtype: int64

# %%
df1.to_csv(r'C:\Users\user\Downloads\crime_bd.csv', index=False)

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC        OFNS_DESC PERP_SEX  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        F
# 512672   2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS        M
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# ...             ...                          ...              ...      ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
#
#               PERP_RACE ARREST_YEAR
# ...

# %%
df1 = df1[(df1['ARREST_YEAR'] > '2011')]

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC PERP_SEX       PERP_RACE  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5        F           BLACK
# 512672   2014-08-04          SALE SCHOOL GROUNDS        M           BLACK
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5        M           BLACK
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5        M           BLACK
# ...             ...                          ...      ...             ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5        M           BLACK
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M  WHITE HISPANIC
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5        M           BLACK
#
#         ARREST_YEAR
# 512597         2014
# 512645         2014
# ...

# %%
df1['Weekday'],df1['Day'],df1['Month'],= df1.ARREST_DATE.dt.strftime('%A'),df1.ARREST_DATE.dt.strftime('%d'),df1.ARREST_DATE.dt.strftime('%b')
df1.head()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\2667782742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1['Weekday'],df1['Day'],df1['Month'],= df1.ARREST_DATE.dt.strftime('%A'),df1.ARREST_DATE.dt.strftime('%d'),df1.ARREST_DATE.dt.strftime('%b')
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\2667782742.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df1.groupby('PD_DESC').count()
# Out:
#                                              ARREST_DATE  PERP_SEX  PERP_RACE  \
# PD_DESC
# CONTROLLED SUBSTANCE, INTENT TO SELL 5               913       913        913
# CONTROLLED SUBSTANCE, POSSESSI                         1         1          1
# CONTROLLED SUBSTANCE, POSSESSION 4                   320       320        320
# CONTROLLED SUBSTANCE, POSSESSION 5                   453       453        453
# CONTROLLED SUBSTANCE, POSSESSION 7                  8097      8097       8097
# CONTROLLED SUBSTANCE, SALE 4                          23        23         23
# CONTROLLED SUBSTANCE, SALE 5                         137       137        137
# CONTROLLED SUBSTANCE,INTENT TO SELL 3               5208      5208       5208
# CONTROLLED SUBSTANCE,POSSESS. 1                      214       214        214
# CONTROLLED SUBSTANCE,POSSESS. 2                      284       284        284
# CONTROLLED SUBSTANCE,POSSESS. 3                      115       115        115
# ...

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC        OFNS_DESC PERP_SEX  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        F
# 512672   2014-08-04          SALE SCHOOL GROUNDS  DANGEROUS DRUGS        M
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# ...             ...                          ...              ...      ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5  DANGEROUS DRUGS        M
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5  DANGEROUS DRUGS        M
#
#               PERP_RACE ARREST_YEAR    Weekday Day Month
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                             PD_DESC  \
# 3          32311380  2007-06-18  CONTROLLED SUBSTANCE, POSSESSION 7
# 512402    140379311  2014-12-31                              RAPE 1
# 512444    140141998  2014-12-11                              RAPE 1
# 512445    140066034  2014-12-05     IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                         ARSON 2,3,4
# ...             ...         ...                                 ...
# 5203175    26276767  2007-01-13         BURGLARS TOOLS,UNCLASSIFIED
# 5203198    26172900  2007-01-08         MARIJUANA, POSSESSION 4 & 5
# 5203201    26242320  2007-01-11         CONTROLLED SUBSTANCE,SALE 3
# 5203208    26094257  2007-01-04         MARIJUANA, POSSESSION 4 & 5
# 5203209    26127635  2007-01-06                    RESISTING ARREST
#
#                                       OFNS_DESC AGE_GROUP PERP_SEX  \
# 3                               DANGEROUS DRUGS     18-24        M
# ...

# %%
df.drop([3])
# Out:
#          ARREST_KEY ARREST_DATE                          PD_DESC  \
# 512402    140379311  2014-12-31                           RAPE 1
# 512444    140141998  2014-12-11                           RAPE 1
# 512445    140066034  2014-12-05  IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                      ARSON 2,3,4
# 512464    140079962  2014-12-07                STRANGULATION 1ST
# ...             ...         ...                              ...
# 5203175    26276767  2007-01-13      BURGLARS TOOLS,UNCLASSIFIED
# 5203198    26172900  2007-01-08      MARIJUANA, POSSESSION 4 & 5
# 5203201    26242320  2007-01-11      CONTROLLED SUBSTANCE,SALE 3
# 5203208    26094257  2007-01-04      MARIJUANA, POSSESSION 4 & 5
# 5203209    26127635  2007-01-06                 RESISTING ARREST
#
#                                       OFNS_DESC AGE_GROUP PERP_SEX  \
# 512402                                     RAPE     18-24        M
# ...

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                             PD_DESC  \
# 3          32311380  2007-06-18  CONTROLLED SUBSTANCE, POSSESSION 7
# 512402    140379311  2014-12-31                              RAPE 1
# 512444    140141998  2014-12-11                              RAPE 1
# 512445    140066034  2014-12-05     IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                         ARSON 2,3,4
# ...             ...         ...                                 ...
# 5203175    26276767  2007-01-13         BURGLARS TOOLS,UNCLASSIFIED
# 5203198    26172900  2007-01-08         MARIJUANA, POSSESSION 4 & 5
# 5203201    26242320  2007-01-11         CONTROLLED SUBSTANCE,SALE 3
# 5203208    26094257  2007-01-04         MARIJUANA, POSSESSION 4 & 5
# 5203209    26127635  2007-01-06                    RESISTING ARREST
#
#                                       OFNS_DESC AGE_GROUP PERP_SEX  \
# 3                               DANGEROUS DRUGS     18-24        M
# ...

# %%
df['Weekday'],df['Day'],df['Month'],= df.ARREST_DATE.dt.strftime('%A'),df.ARREST_DATE.dt.strftime('%d'),df.ARREST_DATE.dt.strftime('%b')
df.head()
# Out:
#         ARREST_KEY ARREST_DATE                             PD_DESC  \
# 3         32311380  2007-06-18  CONTROLLED SUBSTANCE, POSSESSION 7
# 512402   140379311  2014-12-31                              RAPE 1
# 512444   140141998  2014-12-11                              RAPE 1
# 512445   140066034  2014-12-05     IMPERSONATION 2, PUBLIC SERVANT
# 512447   139933331  2014-12-03                         ARSON 2,3,4
#
#               OFNS_DESC AGE_GROUP PERP_SEX       PERP_RACE  X_COORD_CD  \
# 3       DANGEROUS DRUGS     18-24        M           BLACK         NaN
# 512402             RAPE     18-24        M           BLACK   1035212.0
# 512444             RAPE     18-24        M           BLACK   1053678.0
# 512445           FRAUDS     18-24        M           BLACK    997252.0
# 512447            ARSON     18-24        M  WHITE HISPANIC   1016323.0
#
#         Y_COORD_CD   Latitude  Longitude ARREST_YEAR    Weekday Day Month
# ...

# %%
df=df.drop([3])

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                          PD_DESC  \
# 512402    140379311  2014-12-31                           RAPE 1
# 512444    140141998  2014-12-11                           RAPE 1
# 512445    140066034  2014-12-05  IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                      ARSON 2,3,4
# 512464    140079962  2014-12-07                STRANGULATION 1ST
# ...             ...         ...                              ...
# 5203175    26276767  2007-01-13      BURGLARS TOOLS,UNCLASSIFIED
# 5203198    26172900  2007-01-08      MARIJUANA, POSSESSION 4 & 5
# 5203201    26242320  2007-01-11      CONTROLLED SUBSTANCE,SALE 3
# 5203208    26094257  2007-01-04      MARIJUANA, POSSESSION 4 & 5
# 5203209    26127635  2007-01-06                 RESISTING ARREST
#
#                                       OFNS_DESC AGE_GROUP PERP_SEX  \
# 512402                                     RAPE     18-24        M
# ...

# %%
plt.figure(figsize=(8,8))    #We are giving the size of figure
sns.countplot(x=df1.Weekday)  #countplot taking counts of the columns which you choose 
plt.show()

# %%
plt.figure(figsize=(8,8))    #We are giving the size of figure
sns.countplot(x=df1.Month)  #countplot taking counts of the columns which you choose 
plt.show()

# %%
year_count = []

for i in df1.ARREST_YEAR.unique():
    year_count.append(len(df1[df1['ARREST_YEAR']==i]))

plt.figure(figsize=(10,5))
sns.pointplot(x=df1.ARREST_YEAR.unique(),y=year_count,color='red',alpha=0.8)
plt.xlabel('Year',fontsize = 15,color='blue')
plt.xticks(rotation=45)
plt.ylabel('Crime Count',fontsize = 15,color='blue')
plt.title('Crime vs Year',fontsize = 15,color='blue')
plt.grid()
plt.show()

# %%
pip install basemap
# Out:
# ...
#
# ...

# %%
from mpl_toolkits.basemap import Basemap

m = Basemap(projection='mill',llcrnrlat=25,urcrnrlat=49.5,\
            llcrnrlon=-140,urcrnrlon=-50,resolution='l')

plt.figure(figsize=(25,17))
m.drawcountries() #for drawing country borders
m.drawstates()    #for drawing states borders
m.drawcoastlines()
#m.fillcontinents(color='#04BAE3', lake_color='#FFFFFF') #giving color 

lat = 40.586466
lon = -73.816522

x,y = m(lon,lat)
m.plot(x, y, 'ro', markersize=20, alpha=.8) #alpha is making your marker transparent

m.bluemarble() #With this it's make your map like from satellite but if you give colors it will not work
m.drawmapboundary(color = '#FFFFFF')
plt.show()

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import folium
from folium.plugins import HeatMap

map_hooray = folium.Map(location=[40.586466,-73.989282],
                    zoom_start = 12, min_zoom=12) #Giving the location just write boston coordinat to google

heat_df = df[df['ARREST_YEAR']==2013] # I take 2017 cause there is more crime against to other years
heat_df = heat_df[heat_df['OFNS_DESC']=='DANGEROUS DRUGS'] 
heat_df = heat_df[['Latitude', 'Longitude']] #giving only latitude and longitude now in heat_df just latitude and longitude
                                        #from 2017 larceny responde


    
    
folium.CircleMarker([40.586466,-73.989282],
                    radius=50,
                    popup='Homicide',
                    color='red',
                    ).add_to(map_hooray) #Adding mark on the map but it's hard to find correct place. 
                                         #it's take to muhc time
    
    
heat_data = [[row['Latitude'],row['Longitude']] for index, row in heat_df.iterrows()]
#We have to give latitude and longitude like this [[lat, lon],[lat, lon],[lat, lon],[lat, lon],[lat, lon]]

HeatMap(heat_data, radius=10).add_to(map_hooray) #Adding map_hooray to HeatMap
map_hooray #Plotting
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df
# Out:
#          ARREST_KEY ARREST_DATE                          PD_DESC  \
# 512402    140379311  2014-12-31                           RAPE 1
# 512444    140141998  2014-12-11                           RAPE 1
# 512445    140066034  2014-12-05  IMPERSONATION 2, PUBLIC SERVANT
# 512447    139933331  2014-12-03                      ARSON 2,3,4
# 512464    140079962  2014-12-07                STRANGULATION 1ST
# ...             ...         ...                              ...
# 5203175    26276767  2007-01-13      BURGLARS TOOLS,UNCLASSIFIED
# 5203198    26172900  2007-01-08      MARIJUANA, POSSESSION 4 & 5
# 5203201    26242320  2007-01-11      CONTROLLED SUBSTANCE,SALE 3
# 5203208    26094257  2007-01-04      MARIJUANA, POSSESSION 4 & 5
# 5203209    26127635  2007-01-06                 RESISTING ARREST
#
#                                       OFNS_DESC AGE_GROUP PERP_SEX  \
# 512402                                     RAPE     18-24        M
# ...

# %%
#Data
day_order = ["Monday", "Tuesday", "Wednesday","Thursday","Friday","Saturday","Sunday"]

fig,(ax1,ax2) = plt.subplots(2,1, figsize=[15,10])

sns.countplot("Weekday", data=df,order=day_order,palette="RdBu_r",edgecolor="black", ax = ax1)
ax1.set_xlabel("Days of the week", alpha=0.75)
ax1.set_ylabel("Number of crimes", alpha=0.75)

sns.countplot("Day", data=df,palette="RdBu_r",edgecolor="black", ax = ax2)
ax2.set_xlabel("Day", alpha=0.75)
ax2.set_ylabel("Number of crimes", alpha=0.75)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\user\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'Number of crimes')

# %%
ax,fig = plt.subplots(figsize=(15,7))

#Plot
sns.countplot(y = df["OFNS_DESC"],order=df["OFNS_DESC"].value_counts()[:10].index, palette="RdBu_r",edgecolor="black")

plt.ylabel("Crime Type", fontsize=22, alpha=.75)
plt.xlabel("Number of crimes committed", fontsize=22, alpha=.75)

plt.yticks(alpha=0.75,weight="bold")
plt.xticks(alpha=0.75)
# Out:
# (array([     0.,  50000., 100000., 150000., 200000., 250000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
ax,fig = plt.subplots(figsize=(15,7))

#Plot
sns.countplot(y = df["PD_DESC"],order=df["PD_DESC"].value_counts()[:10].index, palette="RdBu_r",edgecolor="black")

plt.ylabel("Crime Type", fontsize=22, alpha=.75)
plt.xlabel("Number of crimes committed", fontsize=22, alpha=.75)

plt.yticks(alpha=0.75,weight="bold")
plt.xticks(alpha=0.75)
# Out:
# (array([     0.,  20000.,  40000.,  60000.,  80000., 100000., 120000.,
#         140000., 160000.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
df1.drop(df1.columns[[2]], axis=1, inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_19092\4237081239.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.columns[[2]], axis=1, inplace=True)

# %%
df1
# Out:
#         ARREST_DATE                      PD_DESC PERP_SEX       PERP_RACE  \
# 512597   2014-09-16  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 512645   2014-08-25  MARIJUANA, POSSESSION 4 & 5        F           BLACK
# 512672   2014-08-04          SALE SCHOOL GROUNDS        M           BLACK
# 512675   2014-08-01        MARIJUANA, SALE 4 & 5        M           BLACK
# 512679   2014-07-31        MARIJUANA, SALE 4 & 5        M           BLACK
# ...             ...                          ...      ...             ...
# 3153106  2012-01-11  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 3153111  2012-01-11        MARIJUANA, SALE 4 & 5        M           BLACK
# 3153114  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M  WHITE HISPANIC
# 3153196  2012-01-05  MARIJUANA, POSSESSION 4 & 5        M           BLACK
# 3153201  2012-01-06        MARIJUANA, SALE 4 & 5        M           BLACK
#
#         ARREST_YEAR    Weekday Day Month
# ...

# %%
df1.to_csv(r'C:\Users\user\Downloads\crime2_bd.csv',index=False)
